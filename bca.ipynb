# %%
from bs4 import BeautifulSoup
import requests
import yfinance as yf
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# %%
bca = yf.Ticker("BBCA")

# %%
bca_data = bca.history(period="max")

# %%
bca_data
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2018-08-09 00:00:00-04:00  42.276630  42.276630  42.276630  42.276630
# 2018-08-10 00:00:00-04:00  42.310848  42.310848  42.310848  42.310848
# 2018-08-13 00:00:00-04:00  42.054229  42.139773  41.883137  41.985794
# 2018-08-14 00:00:00-04:00  42.225307  42.550381  42.225307  42.550381
# 2018-08-15 00:00:00-04:00  41.746245  41.968665  41.472499  41.592262
# ...                              ...        ...        ...        ...
# 2024-12-02 00:00:00-05:00  75.500000  75.500000  74.690002  75.180000
# 2024-12-03 00:00:00-05:00  75.309998  75.519997  74.930000  75.070000
# 2024-12-04 00:00:00-05:00  75.300003  75.480003  74.900002  75.129997
# 2024-12-05 00:00:00-05:00  75.199997  75.620003  75.139999  75.480003
# 2024-12-06 00:00:00-05:00  75.419998  75.419998  74.779999  74.910004
#
#                             Volume  Dividends  Stock Splits  Capital Gains
# Date
# ...

# %%
bca_data.reset_index(inplace=True)
bca_data
# Out:
#       index                      Date       Open       High        Low  \
# 0         0 2018-08-09 00:00:00-04:00  42.276630  42.276630  42.276630
# 1         1 2018-08-10 00:00:00-04:00  42.310848  42.310848  42.310848
# 2         2 2018-08-13 00:00:00-04:00  42.054229  42.139773  41.883137
# 3         3 2018-08-14 00:00:00-04:00  42.225307  42.550381  42.225307
# 4         4 2018-08-15 00:00:00-04:00  41.746245  41.968665  41.472499
# ...     ...                       ...        ...        ...        ...
# 1588   1588 2024-12-02 00:00:00-05:00  75.500000  75.500000  74.690002
# 1589   1589 2024-12-03 00:00:00-05:00  75.309998  75.519997  74.930000
# 1590   1590 2024-12-04 00:00:00-05:00  75.300003  75.480003  74.900002
# 1591   1591 2024-12-05 00:00:00-05:00  75.199997  75.620003  75.139999
# 1592   1592 2024-12-06 00:00:00-05:00  75.419998  75.419998  74.779999
#
#           Close   Volume  Dividends  Stock Splits  Capital Gains
# ...

# %%
url = "https://www.bca.co.id/en/tentang-bca/Hubungan-Investor/Informasi-Saham/Harga-Kinerja-Saham"
soup = BeautifulSoup(requests.get(url).text, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
# <!--<![endif]-->
# <head>
# <!-- Google Tag Manager -->
# <script>
#             (function (w, d, s, l, i) {
#                 w[l] = w[l] || []; w[l].push({
#                     'gtm.start':
#                         new Date().getTime(), event: 'gtm.js'
#                 }); var f = d.getElementsByTagName(s)[0],
#                 j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#             })(window, document, 'script', 'dataLayer', 'GTM-KGCJ5M');
#         </script>
# <!-- End Google Tag Manager -->
# <!-- Meiro Tracking Code Start -->
# ...
